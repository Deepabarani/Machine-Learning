# %% [markdown]
# <a href="https://colab.research.google.com/github/Deepabarani/Machine-Learning/blob/main/ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hi")
# Out:
# hi

# %%
pip install numpy

# %%
import numpy as np

data = np.array([[1,3,4],[5,7,8]])
print(data)
# Out:
# [[1 3 4]
#  [5 7 8]]

# %%
data = np.array([[1,3,4],[5,7,8]])
data1 = data.reshape(3,2)
print(data1)
# Out:
# [[1 3]
#  [4 5]
#  [7 8]]

# %%
a = np.array([1,2])
b = np.array([7,0])
c = a + b
c
# Out:
# array([8, 2])

# %%
# broadcasting with scalar

a = np.array([1,2,3,4])
b = 10
c = a + b
c
# Out:
# array([11, 12, 13, 14])

# %%
#sum of array values

a = np.array([[5,6,8],[7,8,9]])
c = np.sum(a)
c
# Out:
# 43

# %%
#sum of array column values

a = np.array([[5,6,8],[7,8,9]])
c = np.sum(a, axis=0)
c
# Out:
# array([12, 14, 17])

# %%
#sum of array rows values

a = np.array([[5,6,8],[7,8,9]])
c = np.sum(a, axis=1)
c
# Out:
# array([19, 24])

# %%
pip install pandas

# %%
import pandas as pd
a = [2,4,6,8]
series = pd.Series(a)
series
# Out:
# 0    2
# 1    4
# 2    6
# 3    8
# dtype: int64

# %%
a = [2,4,6,8]
custom = ["a", "b", "c", "d"]
series = pd.Series(a, index=custom)
series
# Out:
# a    2
# b    4
# c    6
# d    8
# dtype: int64

# %%
series[2]
# Out:
# 6

# %%
sum = series + 5
sum
# Out:
# a     7
# b     9
# c    11
# d    13
# dtype: int64

# %%
#data frames

data = {
    "name": ["deepa", "helen"],
    "age": ["35", "33"],
    "id": ["01", "02"]
}
df = pd.DataFrame(data)
df
# Out:
#     name age  id
# 0  deepa  35  01
# 1  helen  33  02

# %%
df["name"]
# Out:
# 0    deepa
# 1    helen
# Name: name, dtype: object

# %%
df.loc[0]
# Out:
# name    deepa
# age        35
# id         01
# Name: 0, dtype: object

# %%
from google.colab import files
import pandas as pd
import io

# Upload the file from your local machine
uploaded = files.upload()

# Iterate through the uploaded files and read them using pandas
for filename in uploaded.keys():
    print('User uploaded file "{name}" with length {length} bytes'.format(
        name=filename, length=len(uploaded[filename])))

    # Read the uploaded file into a pandas DataFrame

    df = pd.read_csv(io.BytesIO(uploaded[filename]))
    print(df.head())  # Display the first few rows of the DataFrame
# Out:
#      <input type="file" id="files-ed4daac7-d702-4687-9bb1-4df7015a7d35" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ed4daac7-d702-4687-9bb1-4df7015a7d35">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
 pd.options.display.max_rows=100

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   NO      10 non-null     int64
#  1   Name    10 non-null     object
#  2   Age     7 non-null      float64
#  3   Scores  8 non-null      float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 448.0+ bytes

# %%
df.describe()
# Out:
#              NO         Age      Scores
# count  10.00000    7.000000    8.000000
# mean    5.50000   55.714286   80.750000
# std     3.02765   35.813006   19.418327
# min     1.00000   17.000000   44.000000
# 25%     3.25000   27.000000   74.000000
# 50%     5.50000   45.000000   81.500000
# 75%     7.75000   82.500000   98.250000
# max    10.00000  109.000000  100.000000

# %%
#to check null
df.isna()
# Out:
#       NO   Name    Age  Scores
# 0  False  False  False   False
# 1  False  False  False   False
# 2  False  False   True   False
# 3  False  False  False    True
# 4  False  False   True   False
# 5  False  False  False   False
# 6  False  False  False   False
# 7  False  False  False   False
# 8  False  False  False   False
# 9  False  False   True    True

# %%
#to replace a particular row null value => df["Age"].fillna(22, inplace=True)
df["Age"].fillna(88, inplace=True)
df
# Out:
#    NO       Name    Age  Scores
# 0   1      Deepa   17.0    99.0
# 1   2      Helen   20.0    98.0
# 2   3  Saravanan   88.0    85.0
# 3   4      Mohan   34.0     NaN
# 4   5      Divya   88.0    77.0
# 5   6      Kalps   45.0    44.0
# 6   7       Navi   88.0    65.0
# 7   8     Mangai   77.0    78.0
# 8   9       Siva  109.0   100.0
# 9  10       Yaro   88.0     NaN

# %%
x = df["Age"].mean()
x
# Out:
# 65.4

# %%
#Toreplace mean/mode/median
# x = df["Age"].mode()[0]
df["Scores"].fillna(x, inplace=True)
df
# Out:
#    NO       Name    Age  Scores
# 0   1      Deepa   17.0    99.0
# 1   2      Helen   20.0    98.0
# 2   3  Saravanan   88.0    85.0
# 3   4      Mohan   34.0    65.4
# 4   5      Divya   88.0    77.0
# 5   6      Kalps   45.0    44.0
# 6   7       Navi   88.0    65.0
# 7   8     Mangai   77.0    78.0
# 8   9       Siva  109.0   100.0
# 9  10       Yaro   88.0    65.4

# %%
# To drop duplicate rows
# df.drop_duplicates(inplace=True)
# df.rename(columns={"Name": "Full Name"}, inplace=True)

# %%
#To Create new Column
df['Medals Count'] = [3,5,7,1,8,4,7,4,10,1]
df
# Out:
#    NO       Name    Age  Scores  Medals Count
# 0   1      Deepa   17.0    99.0             3
# 1   2      Helen   20.0    98.0             5
# 2   3  Saravanan   88.0    85.0             7
# 3   4      Mohan   34.0    65.4             1
# 4   5      Divya   88.0    77.0             8
# 5   6      Kalps   45.0    44.0             4
# 6   7       Navi   88.0    65.0             7
# 7   8     Mangai   77.0    78.0             4
# 8   9       Siva  109.0   100.0            10
# 9  10       Yaro   88.0    65.4             1

# %%
df.drop(columns=['Name']).corr()
# Out:
#                     NO       Age    Scores  Medals Count
# NO            1.000000  0.734195 -0.358417      0.098473
# Age           0.734195  1.000000 -0.058406      0.581394
# Scores       -0.358417 -0.058406  1.000000      0.382296
# Medals Count  0.098473  0.581394  0.382296      1.000000

# %%
df.plot(kind='bar', x='Age', y='Scores')
# Out:
# <Axes: xlabel='Age'>

# %%
import matplotlib.pyplot as plt

# %%
df.plot(kind='scatter', x='Age', y='Scores', color='blue')
# Out:
# <Axes: xlabel='Age', ylabel='Scores'>

# %%
df.plot(kind='scatter', x='Age', y='Scores', color='green')
plt.xlabel('Age')
plt.ylabel("Scores")
plt.title("Scatter Plot")
plt.show()
